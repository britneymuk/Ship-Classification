# %% [markdown]
# https://www.youtube.com/watch?v=57N1g8k2Hwc&ab_channel=ShriramVasudevan

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d5016d72-4979-4e59-9777-91e8570a2856" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5016d72-4979-4e59-9777-91e8570a2856">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"britneymukyuenkuan","key":"cbaea59e3a76abc4bd6dada6333d9e75"}'}

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arpitjain007/game-of-deep-learning-ship-datasets
# Out:
# ...
#  90% 73.0M/80.9M [00:00<00:00, 161MB/s]
# 100% 80.9M/80.9M [00:00<00:00, 136MB/s]

# %%
# !unzip game-of-deep-learning-ship-datasets.zip -d /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829342.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829344.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829347.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829351.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829357.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829359.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829362.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829366.jpg
#   inflating: /content/drive/MyDrive/UCCD3074_Labs/Assignment2/input/train/images/2829369.jpg
# ...
